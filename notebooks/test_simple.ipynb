# %%
from audapter.driver.filter_driver import FilterDriver

# %%
import numpy as np
from scipy.fft import fft, ifft, fftfreq
from matplotlib import pyplot as plt

# %%
# Period
T_msec = 100

# Sample rate
fs = 44100

# Time
t = np.linspace(0, 1, fs)
t = t[: (fs*T_msec)//1000]

# %%
# Frequency of sound
w_sound = 20

# Input(by sound system)
x = np.sin(w_sound * (2 * np.pi * t))

# %%
# Desired(equals to 'x')
d = x[:]

# %%
# Output(by sound-field)
y = x + np.random.normal(0, 0.1, x.shape)

# %%
x[:10], d[:10], y[:10]
# Out:
# (array([0.        , 0.00284958, 0.00569913, 0.00854864, 0.01139808,
#         0.01424743, 0.01709666, 0.01994575, 0.02279468, 0.02564342]),
#  array([0.        , 0.00284958, 0.00569913, 0.00854864, 0.01139808,
#         0.01424743, 0.01709666, 0.01994575, 0.02279468, 0.02564342]),
#  array([-0.11267446, -0.06745428, -0.06369859,  0.13521364,  0.0316724 ,
#         -0.00538345, -0.01843566,  0.13097498,  0.05140697,  0.12414383]))

# %%
plt.plot(t, x, label="x: Input")
plt.xlabel("Time[sec]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(t, d, label="d: Desired")
plt.xlabel("Time[sec]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(t, y, label="y: Output(rec by sound-field)")
plt.xlabel("Time[sec]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid()
plt.show()

# %%
# DFT
X = np.abs(fft(x, n=fs))
D = np.abs(fft(d, n=fs))
Y = np.abs(fft(y, n=fs))

# Frequency
omega = np.arange(0, fs)

# %%
plt.plot(omega, np.log10(X), label="X: Input")
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(omega, np.log10(D), label="D: Desired")
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(omega, np.log10(Y), label="Y: Output(rec by sound-field)")
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.legend()
plt.grid()
plt.show()
